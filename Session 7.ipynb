# %% [markdown]
# + **حذف نویز گوسی با فیلتر بلوری**

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from skimage import io
from skimage import img_as_float

# %%
image_folder = "images"
im_check = os.path.join(image_folder,"cameraman.tif")

# %%
im1 = io.imread(im_check)
im1 = img_as_float(im1)

# %%
from skimage.feature import corner_harris,corner_peaks,corner_subpix

# %%
plt.imshow(im1,cmap="gray")

# %%
from tensorflow import keras

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(4,11,padding="same",activation="relu",input_shape=[512,512,1]))
model.add(keras.layers.MaxPooling2D(2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3096/1319467194.py in <module>
#       2 conv1 = model.add(keras.layers.SeparableConv2D(4,11,padding="same",input_shape=[512,512,1]))
#       3 conv2 = model.add(keras.layers.SeparableConv2D(4,11,padding="same",dilation_rate=(2,2)))
# ----> 4 layer3 = model.add(keras.layers.Concatenate(axis=-1)([conv1,conv2]))
#       5 model.add(keras.layers.MaxPooling2D(2))
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\keras\layers\merge.py in build(self, input_shape)
#     499     # Used purely for shape validation.
#     500     if not isinstance(input_shape[0], tuple) or len(input_shape) < 1:
# --> 501       raise ValueError(
#     502           'A `Concatenate` layer should be called on a list of '
#     503           f'at least 1 input. Received: input_shape={input_shape}')
#
# ValueError: A `Concatenate` layer should be called on a list of at least 1 input. Received: input_shape=(None, None)

# %%
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 512, 512, 1)]     0
#
#  conv2d_157 (Conv2D)         (None, 512, 512, 1)       10
#
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %%
x[...,0].shape[1:3]
# Out:
# TensorShape([512, 512])

# %%
im2 = im1.reshape((1,512,512))
x = model(im2)
plt.imshow(x[...,0].numpy().reshape(x[...,0].shape[1:3]),interpolation="nearest",cmap="gray")

# %%
Conv2D(4,11,padding="same",activation="relu"

# %%
n_s = 2
fig, axes = plt.subplots(nrows=n_s,ncols=n_s,figsize=(10,10),subplot_kw={'xticks': [], 'yticks': []})
index = [i for i in range(n_s*n_s)]
for ax,n in zip(axes.flat,index):
    ax.imshow(x[...,n].numpy().reshape(x[...,0].shape[1:3]),interpolation="bilinear",cmap="gray")

# %%
in_A = keras.layers.Input(shape=[512,512,1])
conv1 = keras.layers.Conv2D(4,11,padding="same",activation="relu")(in_A)
conv2 = keras.layers.Conv2D(4,11,padding="same",activation="relu")(conv1)
layer3 = keras.layers.Concatenate(axis=3)([conv2,conv1])
model = keras.Model(inputs=[in_A],outputs=[layer3])

# %%
model.summary()
# Out:
# Model: "model_41"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_48 (InputLayer)          [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d_226 (Conv2D)            (None, 512, 512, 4)  488         ['input_48[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 512, 512, 4)  1940        ['conv2d_226[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 512, 512, 8)  0           ['conv2d_227[0][0]',
#                                                                   'conv2d_226[0][0]']
#
# ==================================================================================================
# Total params: 2,428
# Trainable params: 2,428
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x = model(im2)
x.shape
# Out:
# TensorShape([1, 512, 512, 8])

# %%
plt.imshow(x[...,7].numpy().reshape(x[...,0].shape[1:3]),interpolation="bilinear",cmap="gray")

# %%
n_s = 2
fig, axes = plt.subplots(nrows=n_s,ncols=n_s,figsize=(10,10),subplot_kw={'xticks': [], 'yticks': []})
index = [i for i in range(n_s*n_s)]
for ax,n in zip(axes.flat,index):
    ax.imshow(x[1,...,n].numpy().reshape(x[...,0].shape[1:3]),interpolation="bilinear",cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3096/1636177018.py in <module>
#       3 index = [i for i in range(n_s*n_s)]
#       4 for ax,n in zip(axes.flat,index):
# ----> 5     ax.imshow(x[1,...,n].numpy().reshape(x[...,0].shape[1:3]),interpolation="bilinear",cmap="gray")
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    7184 def raise_from_not_ok_status(e, name):
#    7185   e.message += (" name: " + name if name is not None else "")
# -> 7186   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7187
#    7188
#
# InvalidArgumentError: slice index 1 of dimension 0 out of bounds. [Op:StridedSlice] name: strided_slice/

# %%
n_s = 2
fig, axes = plt.subplots(nrows=n_s,ncols=n_s,figsize=(10,10),subplot_kw={'xticks': [], 'yticks': []})
index = [i for i in range(n_s*n_s)]
for ax,n in zip(axes.flat,index):
    ax.imshow(y[...,n].numpy().reshape(y[...,0].shape[1:3]),interpolation="bilinear",cmap="gray")

# %%
output = tf.nn.conv2d(im2, filter, strides, padding=padding)

# %%
coor_orig = corner_peaks(x,min_distance=5,num_peaks=200)

# %%
coor_subpix = corner_subpix(im1,coor_orig,window_size=11)

# %%
plt.figure(figsize=(10,10))
plt.imshow(im1,cmap="gray")
plt.plot(coor_subpix[:,1],coor_subpix[:,0],"r+")

# %%
from skimage.feature import corner_moravec

# %%
corners = corner_moravec(im1,window_size=3)

# %%
coor_orig = corner_peaks(x,min_distance=5,num_peaks=200)
coor_subpix = corner_subpix(im1,coor_orig,window_size=11)

# %%
plt.figure(figsize=(10,10))
plt.imshow(im1,cmap="gray")
plt.plot(coor_subpix[:,1],coor_subpix[:,0],"r+")

# %%
from skimage.transform import rotate

# %%
im_rotate = rotate(im1,45.0)

# %%
fig, axes = plt.subplots(1,2,figsize=(10,10))
axes[0].imshow(im_noisy,cmap="gray")
axes[0].set_title("PSNR = " + str(np.round(psnr(im_noisy,im1),2))+"\nSSIM = " + str(np.round(ssim(im_noisy,im1),2)))
axes[1].imshow(im_denoise,cmap="gray")
axes[1].set_title("PSNR = " + str(np.round(psnr(im_denoise,im1),2))+"\nSSIM = " + str(np.round(ssim(im_denoise,im1),2)))
# Out:
# Text(0.5, 1.0, 'PSNR = 27.74\nSSIM = 0.83')

# %% [markdown]
# **فیلتر گوسی**

# %%
from skimage.filters import gaussian

# %%
im_denoise = gaussian(im_noisy,sigma=1.2)

# %%
fig, axes = plt.subplots(1,2,figsize=(10,10))
axes[0].imshow(im_noisy,cmap="gray")
axes[0].set_title("PSNR = " + str(np.round(psnr(im_noisy,im1),2))+"\nSSIM = " + str(np.round(ssim(im_noisy,im1),2)))
axes[1].imshow(im_denoise,cmap="gray")
axes[1].set_title("PSNR = " + str(np.round(psnr(im_denoise,im1),2))+"\nSSIM = " + str(np.round(ssim(im_denoise,im1),2)))
# Out:
# Text(0.5, 1.0, 'PSNR = 28.83\nSSIM = 0.89')

# %% [markdown]
# **حذف نویز فلفلی و نمکی  با فیلتر میانه**

# %%
from skimage.filters import median

# %%
im_noisy = random_noise(im1,mode="s&p",amount = 0.05,salt_vs_pepper=0.5)

# %%
im_denoise = median(im_noisy)

# %%
fig, axes = plt.subplots(1,2,figsize=(10,10))
axes[0].imshow(im_noisy,cmap="gray")
axes[0].set_title("PSNR = " + str(np.round(psnr(im_noisy,im1),2))+"\nSSIM = " + str(np.round(ssim(im_noisy,im1),2)))
axes[1].imshow(im_denoise,cmap="gray")
axes[1].set_title("PSNR = " + str(np.round(psnr(im_denoise,im1),2))+"\nSSIM = " + str(np.round(ssim(im_denoise,im1),2)))
# Out:
# Text(0.5, 1.0, 'PSNR = 35.84\nSSIM = 0.99')

# %% [markdown]
# **مشتقات تصویر**

# %% [markdown]
# **فیلتر Sobel**

# %%
from skimage.filters import sobel_h, sobel_v, sobel

# %%
im_checkerboard = os.path.join(image_folder,"checkerboard.tif")
im2 = io.imread(im_checkerboard)

# %%
im_filter_h = sobel_h(im2)
im_filter_v = sobel_v(im2)
im_filter = sobel(im2)

# %%
fig, axes = plt.subplots(1,3,figsize=(10,10))
axes[0].imshow(im_filter_h,cmap="gray")
axes[0].set_title("Gx")
axes[1].imshow(im_filter_v,cmap="gray")
axes[1].set_title("Gy")
axes[2].imshow(im_filter,cmap="gray")
axes[2].set_title("Gxy")
# Out:
# Text(0.5, 1.0, 'Gxy')

# %% [markdown]
# **فیلتر Prewitt**

# %%
from skimage.filters import prewitt_h, prewitt_v, prewitt

# %%
im_filter_h = prewitt_h(im2)
im_filter_v = prewitt_v(im2)
im_filter = prewitt(im2)

# %%
fig, axes = plt.subplots(1,3,figsize=(10,10))
axes[0].imshow(im_filter_h,cmap="gray")
axes[0].set_title("Gx")
axes[1].imshow(im_filter_v,cmap="gray")
axes[1].set_title("Gy")
axes[2].imshow(im_filter,cmap="gray")
axes[2].set_title("Gxy")
# Out:
# Text(0.5, 1.0, 'Gxy')

# %% [markdown]
# **فیلتر Scharr**

# %%
from skimage.filters import scharr_h, scharr_v, scharr

# %%
im_filter_h = scharr_h(im2)
im_filter_v = scharr_v(im2)
im_filter = scharr(im2)

# %%
fig, axes = plt.subplots(1,3,figsize=(10,10))
axes[0].imshow(im_filter_h,cmap="gray")
axes[0].set_title("Gx")
axes[1].imshow(im_filter_v,cmap="gray")
axes[1].set_title("Gy")
axes[2].imshow(im_filter,cmap="gray")
axes[2].set_title("Gxy")
# Out:
# Text(0.5, 1.0, 'Gxy')

# %% [markdown]
# **مشتق مرتبه دوم یا لاپلاسین**

# %%
from skimage.filters import laplace

# %%
im_filter = laplace(im2)

# %%
plt.imshow(im_filter,cmap="gray")

# %% [markdown]
# **لبه یابی**

# %%
im_church = os.path.join(image_folder,"church.gif")
im3 = io.imread(im_church)

# %%
from skimage.filters import roberts

# %%
im_filter_robert = roberts(im3)
im_filter_scharr = scharr(im3)
im_filter_sobel = sobel(im3)
im_filter_prewitt = prewitt(im3)
im_filter_laplace = laplace(im3)

# %%
fig, axes = plt.subplots(2,3,figsize=(15,15))
axes[0,0].imshow(im_filter_robert,cmap="gray")
axes[0,0].set_title("roberts")
axes[0,1].imshow(im_filter_scharr,cmap="gray")
axes[0,1].set_title("scharr")
axes[0,2].imshow(im_filter_sobel,cmap="gray")
axes[0,2].set_title("sobel")
axes[1,0].imshow(im_filter_prewitt,cmap="gray")
axes[1,0].set_title("prewitt")
axes[1,1].imshow(np.clip(im_filter_laplace,0,1),cmap="gray")
axes[1,1].set_title("laplace")
axes[1,2].imshow(im3,cmap="gray")
axes[1,2].set_title("Original")
# Out:
# Text(0.5, 1.0, 'Original')

# %%
from skimage.feature import canny

# %%
im_filter = canny(im3,sigma=2.0)

# %%
plt.imshow(im_filter,cmap="gray")

# %%
from skimage.filters import difference_of_gaussians

# %%
sigma = 1
im_filter = difference_of_gaussians(im3, sigma)# high_sigma = 1.6xsigma

# %%
plt.imshow(im_filter,cmap="gray")

# %%
im_filter_copy = np.copy(im_filter)
im_filter_copy[im_filter_copy >= 0] = 1.0
im_filter_copy[im_filter_copy < 0] = 0
plt.imshow(im_filter_copy,cmap="gray")

# %%
im_astro = os.path.join(image_folder,"plate.png")
im4 = io.imread(im_astro,as_gray=True)

# %%
from skimage import img_as_float
im4 = img_as_float(im4)

# %%
from skimage.transform.pyramids import pyramid_laplacian

# %%
pyramids = tuple(pyramid_laplacian(im1,downscale=2,max_layer=5))

# %%
fig, axes = plt.subplots(1,6,figsize=(15,15))
i = 0
for p in pyramids:
    axes[i].imshow(p,cmap="gray")
    axes[i].set_title(str(p.shape))#show image size
    axes[i].axis("off")
    i += 1

# %% [markdown]
# **بازسازی**

# %%
from skimage.transform.pyramids import pyramid_expand

# %%
w1 = pyramid_expand(pyramids[5]) + pyramids[4]
w2 = pyramid_expand(w1) + pyramids[3]
w3 = pyramid_expand(w2) + pyramids[2]
w4 = pyramid_expand(w3) + pyramids[1]
w5 = pyramid_expand(w4) + pyramids[0]
im_reconstructed = w5

# %%
plt.imshow(im_reconstructed,cmap="gray")

# %%
hlaf_w = int(W/2)
half_h = int(H/2)

# %%
im_shift[hlaf_w-20:hlaf_w+21,half_h-20:half_h+21] = 0

# %%
plt.imshow(20*np.log10(0.01+np.abs(im_shift)),cmap="gray")

# %%
plt.figure(figsize=(7,7))
im_filter = np.abs(ifft2(fftshift(im_shift)))
plt.imshow(im_filter)

# %% [markdown]
# **بازیابی تصاویر با روش فیلتر معکوس**

# %%
plt.imshow(im_reconstruct)

# %%
epsilon = 1e-6
inverse_kernel = 1/(epsilon + gaussian_kernel_frq)

# %%
im_reconstruct_frq = fft2(im_reconstruct)

# %%
im_restor_frq = im_reconstruct_frq * inverse_kernel

# %%
im_restor = np.abs(fftshift(ifft2(im_restor_frq)))

# %%
plt.imshow(im_restor)

# %% [markdown]
# اختلاف تصویر بازیابی شده با تصویر اصلی

# %%
from skimage.util import compare_images
diff = compare_images(im_restor,im1,method='diff')
io.imshow(diff)
